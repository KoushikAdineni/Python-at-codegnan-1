# %%
#codeforces
n1,n2,n3,n4=map(int,input().split())
x=(n1*n2)-(n3*n4)
print("Difference =",x)
# Out:
#  1 2 3 4
# Difference = -10

# %%
x,y=map(int,input().split())
print(f"{x} + {y} = {x + y}")
print(f"{x} * {y} = {x * y}")
print(f"{x} - {y} = {x - y}")
# Out:
#  5 10
# 5 + 10 = 15
# 5 * 10 = 50
# 5 - 10 = -5

# %%
n,m=map(int,input().split())
print((n%10)+(m%10))
# Out:
#  13 12
# 5

# %%
n=int(input())
print(n*(n+1)//2)
# Out:
#  3
# 6

# %%
import math
a,b=map(int,input().split())
x=a/b
print(f"floor {a} / {b} = {math.floor(x)}")
print(f"ceil {a} / {b} = {math.ceil(x)}")
print(f"round {a} / {b} = {math.floor(x+0.5)}")
# Out:
#  10 3
# floor 10 / 3 = 3
# ceil 10 / 3 = 4
# round 10 / 3 = 3

# %%
a,b=map(int,input().split())
if a>=b:
    print("Yes")
else:
    print("No")
# Out:
#  3 4
# No

# %%
a,b=map(int,input().split())
if a%b==0 or b%a==0:
    print("Multiples")
else:
    print("No Multiples")
# Out:
#  12 33
# No Multiples

# %%
a,b,c=map(int,input().split())
print(min(a,b,c),max(a,b,c))
# Out:
#  1 2 3
# 1 3

# %%
F1, S1 = input().split()
F2, S2 = input().split()

if S1 == S2:
    print("ARE Brothers")
else:
    print("NOT")
# Out:
#  ali shaik
#  ram shaik
# ARE Brothers

# %%
x = input()

if x.isdigit():
    print("IS DIGIT")
else:
    print("ALPHA")
    
    if x.isupper():
        print("IS CAPITAL")
    else:
        print("IS SMALL")
# Out:
#  x
# ALPHA
# IS SMALL

# %%
x=input()
if x .islower():
    print(x.upper())
else:
    print(x.lower())
# Out:
#  A
# a

# %%
x = input()
if '+' in x:
    a,b=x.split('+')
    print(int(a)+int(b))
elif '-' in x:
    a,b=x.split('-')
    print(int(a)-int(b))
elif '*' in x:
    a,b=x.split('*')
    print(int(a)*int(b))
else:
    a,b=x.split('/')
    print(int(a)//int(b))
# Out:
#  9139/813
# 11

# %%
exp = input()

if '+' in exp:
    a, b = exp.split('+')
    print(int(a) + int(b))

elif '-' in exp:
    a, b = exp.split('-')
    print(int(a) - int(b))

elif '*' in exp:
    a, b = exp.split('*')
    print(int(a) * int(b))

else:
    a, b = exp.split('/')
    print(int(a) // int(b))
# Out:
#  9139//888
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 16
#      12     a, b = exp.split('*')
#      13     print(int(a) * int(b))
#      14
#      15 else:
# ---> 16     a, b = exp.split('/')
#      17     print(int(a) // int(b))
#
# ValueError: too many values to unpack (expected 2)

# %%
s = input()

if '+' in s:
    a, b = s.split('+')
    print(int(a) + int(b))

elif '-' in s:
    a, b = s.split('-')
    print(int(a) - int(b))

elif '*' in s:
    a, b = s.split('*')
    print(int(a) * int(b))

else:
    a, b = s.split('/')
    print(int(a) // int(b))
# Out:
#  9139/888
# 10

# %%
x=input()
first_digit=int(x[0])
if first_digit%2==0:
    print("EVEN")
else:
    print("ODD")
# Out:
#  35678
# odd

# %%
x,y=map(float,input().split())
if x==0 and y==0:
    print("Origem")
elif x == 0:
    print("Eixo Y")

elif y == 0:
    print("Eixo X")
elif x>0 and y>0:
    print("Q1")
elif x<0 and y>0:
    print("Q2")
elif x<0 and y<0:
    print("Q3")
else:
    print("Q4")
# Out:
#  630.2 0.0
# Eixo X

# %%
n=int(input())
years=n//365
n=n%365

months=n//30
days=n%30
print(f"{years}years")
print(f"{months}months")
print(f"{days}days")
# Out:
#  400
# 1years
# 1months
# 5days

# %%
x = float(input())

if 0 <= x <= 25:
    print("Interval [0,25]")

elif 25 < x <= 50:
    print("Interval (25,50]")

elif 50 < x <= 75:
    print("Interval (50,75]")

elif 75 < x <= 100:
    print("Interval (75,100]")

else:
    print("Out of Intervals")

# %%
a, b, c = map(int, input().split())

nums = [a, b, c]
sorted_nums = sorted(nums)

for num in sorted_nums:
    print(num)

print()

for num in nums:
    print(num)

# %%
n = float(input())

if n == int(n):
    print("int", int(n))
else:
    print("float", int(n), n - int(n))

# %%
a, s, b = input().split()

a = int(a)
b = int(b)

if s == "<":
    if a < b:
        print("Right")
    else:
        print("Wrong")

elif s == ">":
    if a > b:
        print("Right")
    else:
        print("Wrong")

else:
    if a == b:
        print("Right")
    else:
        print("Wrong")

# %%
l1, r1, l2, r2 = map(int, input().split())

start = max(l1, l2)
end = min(r1, r2)

if start <= end:
    print(start, end)
else:
    print(-1)

# %%
a, b, c, d = map(int, input().split())

result = a * b * c * d

print(result % 100)

# %%
#W
a, s, b, q, c = input().split()

a = int(a)
b = int(b)
c = int(c)

if s == '+':
    result = a + b
elif s == '-':
    result = a - b
else:
    result = a * b

if result == c:
    print("Yes")
else:
    print(result)
# Out:
#  10 - 5 = 5
# Yes

# %%
#Y
a, b, c, d = map(int, input().split())

result = (a * b * c * d) % 100

print(f"{result:02d}")
# Out:
#  5 7 2 4
# 80

# %%
#Z
from math import log

a, b, c, d = map(int, input().split())

if b * log(a) > d * log(c):
    print("YES")
else:
    print("NO")
# Out:
#  3 4 5 6
# NO
