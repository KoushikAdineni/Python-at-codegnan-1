# %%
import math
import sys
import random
import os

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import math
print(math.ceil(4.25)) # it returns upper bound integer value
print(math.floor(4.25)) # it returns lower bound integer value
print(math.factorial(5))
print(math.gcd(10,6,4))
print(math.lcm(10,6,4))
print(math.pow(10,3)) # pow(a,b) it returns float type of a raise to b
print(math.sqrt(9)) # it returns sqrt value of a number
print(math.log10(4)) # To Find the log10 values
# Out:
# 5
# 4
# 120
# 2
# 60
# 1000.0
# 3.0

# %%
help(math.ceil)
# Out:
# Help on built-in function ceil in module math:
#
# ceil(x, /)
#     Return the ceiling of x as an Integral.
#
#     This is the smallest integer >= x.

# %%
import random
print(random.random()) #it generates the random number from 0 to 1
print(random.randint(1,6))
print(random.randint(10000,999999)) #6 digit otp
print(random.choice(['A',1,2,3,4,5,6,7,8,9,'J','Q','K'])) # this function returns the random value from the sequence
print(random.choices(['A',1,2,3,4,5,6,7,8,9,'J','Q','K'], k=13))
arr=['A',1,2,3,4,5,6,7,8,9,'J','Q','K']
random.shuffle(arr)
print(arr)
# Out:
# 0.9941540088503255
# 4
# 927959
# 2
# [4, 4, 'A', 'K', 1, 5, 5, 'K', 'K', 'Q', 9, 'Q', 4]
# [8, 2, 3, 'J', 7, 'A', 1, 6, 4, 'K', 5, 'Q', 9]

# %%
### who will reach the Top(100) in less steps
count =0
rolls =0
print("welcome to the who will reach top in less steps game")
while True:
    input("Throw dice ,please click enter button")
    face_val= random.randint(1,6)

    if count + face_val <=100:
        count += face_val

    rolls += 1
    if count == 100:
        print(f"You reached the Top in {rolls} chances")
        break
    print(f"Your dice value:{face_val}")
    print (f"you are at {count} Position in {rolls} chances")
    print("*" * 50)
# Out:
# welcome to the who will reach top in less steps game
# Throw dice ,please click enter button 3
# Your dice value:3
# you are at 3 Position in 1 chances
# **************************************************
# Throw dice ,please click enter button 4
# Your dice value:2
# you are at 5 Position in 2 chances
# **************************************************
# Throw dice ,please click enter button 4
# Your dice value:3
# you are at 8 Position in 3 chances
# **************************************************
# Throw dice ,please click enter button 4
# Your dice value:5
# you are at 13 Position in 4 chances
# **************************************************
# Throw dice ,please click enter button 3
# Your dice value:3
# you are at 16 Position in 5 chances
# **************************************************
# Throw dice ,please click enter button
# Your dice value:4
# you are at 20 Position in 6 chances
# **************************************************
# ...

# %%
import os
print(os.getcwd()) # It returns the current working Directory
if not os.path.exists('a'): # os.path.exists(path): It return True if path exists
    os.mkdir('a') # This function creates new empty directory
os.chdir('a')
print(os.getcwd())
print(os.listdir("."))
# Out:
# C:\Users\koush\OneDrive\Desktop\python main codegnan
# C:\Users\koush\OneDrive\Desktop\python main codegnan\a
# []

# %%
print(os.getcwd())
print(os.listdir(".")) # This function returns the all files and directories from current paths
os.chdir("..") # This changes the working directory as previous directory
print(os.getcwd())
# Out:
# C:\Users\koush\OneDrive\Desktop\python main codegnan\a
# []
# C:\Users\koush\OneDrive\Desktop\python main codegnan
