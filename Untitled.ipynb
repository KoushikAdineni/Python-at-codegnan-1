# %%
print("hlo")
# Out:
# hlo

# %%
#indexing
s ="codegnan"
print(s[1])
print(s[-2])
# Out:
# o
# a

# %%
#slicing
s="Codegnan"
print(s[5:100])
print(s[1:5:1])
print(s[5:])
print(s[-4:])
print(s[::-1])
print(s[-3::1])
# Out:
# nan
# odeg
# nan
# gnan
# nangedoC
# nan

# %%
# empty string representation
# type() : this function returns the obj datatype
s1=""
s2=str()
print(type(s1))
print(type(s2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
#input
#it returns the value in string
s =input()
print(type(s))
print(s)
# Out:
#  5
# <class 'int'>
# 5

# %%
#string operations
#1.String Concatenation (using + operator)

s1 ="code"
s2 ="gnan"
print(s1+s2)
# Out:
# codegnan

# %%
#immutable
s = "codegnan"
res = s[:1:]+Z+s[2::]
print(res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 #immutable
#       2 s = "codegnan"
# ----> 3 res = s[:1:]+Z+s[2::]
#       4 print(res)
#
# NameError: name 'Z' is not defined
