# %%
units=int(input())
age=int(input())
bill=0
if 0<units<=100: 
    bill=units*1.5
elif 101<=units<=200:
    bill=units*2.5
elif 201<=units<=500:
    bill=units*4
elif units>500:
    bill=units*6
if age>=55:
    bill=bill-bill*10/100
elif units>800:
    bill=units*6*1.05
print(bill)
# Out:
#  250
#  55
# 900.0

# %%
credit_score=int(input())
income=int(input())
liabilites=int(input())
if credit_score>=750 and income>=50000 and liabilites<=20000:
    print("Eligible")
elif 650<credit_score<749 and income>=50000 and liabilites<=20000 :
    print("conditional Eligibility")
elif credit_score<650:
    print("rejected")
else:
    print("not eligible")
# Out:
#  850
#  60000
#  14000
# Eligible

# %%
n=int(input())
sum=0
for i in range(1,11):
    print(n*i)
# Out:
#  3
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
