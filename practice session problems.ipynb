# %%
units=int(input())
age=int(input())
bill=0
if 0<units<=100: 
    bill=units*1.5
elif 101<=units<=200:
    bill=units*2.5
elif 201<=units<=500:
    bill=units*4
elif units>500:
    bill=units*6
if age>=55:
    bill=bill-bill*10/100
elif units>800:
    bill=units*6*1.05
print(bill)
# Out:
#  250
#  55
# 900.0

# %%
n="abc123def456"
